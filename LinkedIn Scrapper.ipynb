# %%
# !pip install selenium
# Out:
# Collecting selenium
#   Using cached selenium-3.141.0-py2.py3-none-any.whl (904 kB)
# Requirement already satisfied: urllib3 in c:\users\gaurav sharma\appdata\roaming\python\python38\site-packages (from selenium) (1.22)
# Installing collected packages: selenium
# Successfully installed selenium-3.141.0

# %%
import requests
from bs4 import BeautifulSoup
from selenium.webdriver.common.keys import Keys
import os,random,sys,time
from selenium import webdriver
import pandas as pd

# %%
from time import time

# %%
#setting path for chromedriver
path="C:\\Users\\Gaurav Sharma\\Desktop\\chromedriver.exe"

# %%
#reading config.txt
user="ymdt142@gmail.com"
password="GHmdt14...8"

# %%
#setting which browser to use
#setting which browser to use
import timeit
import time
start = timeit.default_timer()
browser=webdriver.Chrome(path)
url="https://www.linkedin.com/login?"
browser.get(url) #open the site in chrome
elementID=browser.find_element_by_id("username")
elementID.send_keys(user) #login here
elementID=browser.find_element_by_id("password")
elementID.send_keys(password)
elementID.submit()
profileID="https://www.linkedin.com/in/oleksandra-yelizarova/detail/recent-activity/shares/"
browser.get(profileID)
flag=1
x=0
while flag:
    try:
        new = browser.execute_script("return document.body.scrollHeight")
        browser.execute_script('window.scrollTo(0,document.body.scrollHeight)')
        time.sleep(5)
        last_height = browser.execute_script("return document.body.scrollHeight")
        content=browser.page_source
        if(last_height==new):
            print("true")
            flag=0
        x+=1
    except:
        flag=0
        print("end")
stop = timeit.default_timer()
print(stop-start)
# Out:
# end
# 55.12136399999963

# %%
soup=BeautifulSoup(content,'html.parser')

# %%
container=soup.find_all('div',{'class':'occludable-update ember-view'})

# %%
len(container)
# Out:
# 20

# %% [markdown]
# ### post

# %%
post=[]
for i in range(len(container)):
    try:
        p=container[i].find_all('span',{'class':'break-words'})[0].span.span.text
        post.append(p)
    except:
        try:
            ip=container[i].find_all('span',{'class':'break-words'})[0].span.text
            post.append(ip)
        except:
            print(i,"fail")

# %%
post
# Out:
# ["Struggle to get traffic? Let me lead you in the right direction.Share your website in the comments. I'll provide a FREE analysis:1. A list of relevant keywords with metrics2. Link building analysis3. UX audit4. Technical errors.Connect with me Oleksandra Yelizarova, Anatolii Ulitovskyi, and Svetlana Kindiakova before submitting your website because we're unable to dm you.#seo #digitalmarketing #traffic #marketing #trafficgeneration",
#  "Wanna get traffic? Share your website in the comments. We'll provide a FREE analysis: a list of keywords, UX audit, link building tips, technical errors. Connect with us before submitting your website because we will send the analysis in a DM. #website #websitetraffic #seo #digitalmarketing",
#  'Marketing research is crucial.I can explain why.I often speak with potential clients who can’t get results for a few years.It’s not only my clients.Check the infographic below to scope the whole picture.As you can see, online competition is enormous.Most projects fail because they use generic methods.37% of all online projects have a documented marketing strategy.A tiny percent of them have a well-analyzed content plan.These projects only get results – the rest fail.That’s why I provide marketing research before launching any project.Agree? Comment below.',
#  "Struggle to get traffic? Let me lead you in the right direction.Share your website in the comments. I'll provide a FREE analysis:1. A list of relevant keywords with metrics2. Link building analysis3. UX audit4. Technical errors.Connect with me Oleksandra Yelizarova and Anatolii Ulitovskyi and Svetlana Kindiakova before submitting your website because we're unable to dm you.#seo #digitalmarketing #traffic #marketing #trafficgeneration",
#  'Let`s connect and grow on Friday!1. Like this post2. Follow me/send a connection3. Write your comments4. Tag your friends5. Accept a lot of connections#letsconnect #connection #connect #letsgrow',
#  "Struggle to get traffic? Let me lead you in the right direction.Share your website in the comments. I'll provide a FREE analysis:1. A list of relevant keywords with metrics2. Link building analysis3. UX audit4. Technical errors.Connect with me Oleksandra Yelizarova, Anatolii Ulitovskyi, and Svetlana Kindiakova before submitting your website because we're unable to dm you.#seo #digitalmarketing #traffic #marketing #trafficgeneration",
#  "Wanna get traffic for your website?Add it in the comments.I'll provide a Free analysis and lead you in the right direction.You'll get a list of keywords, technical errors, link building tips, UX audit.Before sharing your website, please, connect with me Oleksandra, Anatolii, and Svetlana because I can't send the analysis to a DM.#website #websitetraffic #seo #digitalmarketing",
#  "Let's CONNECT and GROW!1. Like This Post and Connect with me.2. Write a Comment and Tag your friends.I'm willing to connect with you so much!It doesn't matter who you are because you will be my friend.I also choose LinkedIn because of the following reasons:- higher engagement- simpler to grow my network- more professional audience- almost absence of hating- for fun and business- find new friends and clients.How to grow your Linkedin network? Here is my list:- comment a lot on popular posts- post a lot of valuable content- help and support others.- love what you do, be consistent and patient.#letsconnect #connection #connect #letsgrow",
#  "Struggle to get traffic? Let me lead you in the right direction.Share your website in the comments. I'll provide a FREE analysis:1. A list of relevant keywords with metrics2. Link building analysis3. UX audit4. Technical errors.Connect with me Oleksandra Yelizarova and Anatolii Ulitovskyi before submitting your website because we're unable to dm you.#seo #digitalmarketing #traffic #marketing #trafficgeneration",
#  "Wanna get traffic for your website? Add it in the comments. I'll provide a Free analysis and lead you in the right direction. You'll get a list of keywords, technical errors, link building tips, UX audit. Before sharing your website, please, connect with me Oleksandra, Anatolii, and Svetlana because I can't send the analysis to a DM.#website #websitetraffic #seo #digitalmarketing",
#  "Struggle to get traffic? Let me lead you in the right direction.Share your website in the comments. I'll provide a FREE analysis:1. A list of relevant keywords with metrics2. Link building analysis3. UX audit4. Technical errors.Connect with me Oleksandra Yelizarova, Anatolii Ulitovskyi, and Svetlana Kindiakova before submitting your website because we're unable to dm you.#seo #digitalmarketing #traffic #marketing #trafficgeneration",
#  "Struggle to get traffic? Let me lead you in the right direction.Share your website in the comments. I'll provide a FREE analysis:1. A list of relevant keywords with metrics2. Link building analysis3. UX audit4. Technical errors.Connect with me Oleksandra Yelizarova, Anatolii Ulitovskyi, and Svetlana Kindiakova before submitting your website because we're unable to dm you.#seo #digitalmarketing #traffic #marketing #trafficgeneration",
#  'Marketing research is crucial.I can explain why.We often speak with potential clients who can’t get results for a few years.It’s not only my clients.Check the infographic below to scope the whole picture.As you can see, online competition is enormous.Most projects fail because they use generic methods.Agree? Comment below.',
#  "Struggle to get traffic? Let me lead you in the right direction.Share your website in the comments. I'll provide a FREE analysis:1. A list of relevant keywords with metrics2. Link building analysis3. UX audit4. Technical errors.Connect with me Oleksandra Yelizarova and Anatolii Ulitovskyi before submitting your website because we're unable to dm you.#seo #digitalmarketing #traffic #marketing #trafficgeneration",
#  "Struggle to get traffic? Let me lead you in the right direction.Share your website in the comments. I'll provide a FREE analysis:1. A list of relevant keywords with metrics2. Link building analysis3. UX audit4. Technical errors.Connect with me Oleksandra Yelizarova and Anatolii Ulitovskyi before submitting your website because we're unable to dm you.#seo #digitalmarketing #traffic #marketing #trafficgeneration",
#  'SEO is a long game.You don’t really know you will rank or not because it takes over six months to get the first visible results.91% of all projects never see organic reach because of huge online competition.There are over 1,8 billion websites that wanna get organic reach.So, we want to share with you the most errors why projects fail:- Love what you do and focus on priorities- Stop chasing money- Create the correct content plan- Never rewrite- Create your style- Share something new- Build a loyal audience in social media- Use other channels.',
#  'Let`s connect and grow on Wednesday!1. Like this post2. Follow me/send a connection3. Write your comments4. Tag your friends5. Accept a lot of connections#letsconnect #connection #connect #letsgrow',
#  "Struggle to get traffic? Let me lead you in the right direction.Share your website in the comments. I'll provide a FREE analysis:1. A list of relevant keywords with metrics2. Link building analysis3. UX audit4. Technical errors.Connect with me Oleksandra Yelizarova and Anatolii Ulitovskyi before submitting your website because we're unable to dm you.#seo #digitalmarketing #traffic #marketing #trafficgeneration",
#  'Google boffins recommend that you don’t use a disavow file if you don’t have manual actions.If you have manual actions, then you need to disavow all bad backlinks by using the disavow file on Google Console.For future success only allow White hat link building, and connect through email outreach. Below are my five important elements of outreach:- outreach the right people;- provocative email subject;- create connections;- personalization;- brevity.Outreach tools such as Buzzstream or Pitchbox have built-in features for finding email addresses. However, successful websites have a hierarchy and each employee has their own duties and unique email addresses.',
#  'Today is Friday the 13th - Lucky day! Let`s connect!  1. Like this post2. Follow me/send a connection3. Write your comments4. Tag your friends5. Accept a lot of connections#letsconnect #connection #connect #letsgrow']

# %% [markdown]
# ### image

# %%
img=[]
for i in range(len(container)):
    try:
        src=container[i].find_all('img',{'class':"ivm-view-attr__img--centered feed-shared-image__image feed-shared-image__image--constrained lazy-image ember-view"})[0]['src']
        img.append(src)
    except:
        try:
            src=container[i].find_all('img',{'class':"ivm-view-attr__img--centered feed-shared-image__image lazy-image ember-view"})[0]['src']
            img.append(src)
        except:
            img.append('')

# %%
img
# Out:
# ['',
#  '',
#  'https://media-exp1.licdn.com/dms/image/C4D22AQGO4VjxF_mYEQ/feedshare-shrink_1280-alternative/0/1608545935679?e=1613001600&v=beta&t=JuwLXoaQw67puYMvzm87WX3TSDTyBfe2oJJHZozkrIE',
#  'https://media-exp1.licdn.com/dms/image/C4D22AQEn5tRsJG97pg/feedshare-shrink_800-alternative/0/1608293449501?e=1613001600&v=beta&t=WFGTbaY5ZBiKBS3GUOaY7pBTEVF2Sv_DtbDWMpNsqaQ',
#  'https://media-exp1.licdn.com/dms/image/C4D22AQGb2NQLbs30Lw/feedshare-shrink_2048_1536-alternative/0/1608280740356?e=1613001600&v=beta&t=371B4epRwkKknhs_CEVn3EiLc2RtQcGX6pr8Zj3mC0k',
#  '',
#  '',
#  '',
#  'https://media-exp1.licdn.com/dms/image/C4D22AQFqW6swAqIR2g/feedshare-shrink_800-alternative/0/1607502724731?e=1613001600&v=beta&t=jpguj29tavl2Y5jMVjq014GtMtCPi10Mrr_vcWmJKJI',
#  'https://media-exp1.licdn.com/dms/image/C4D22AQE3BBgetnX_Jg/feedshare-shrink_800-alternative/0/1607006856522?e=1613001600&v=beta&t=gelHzeBliBvsX21tlNR5a--pXOKajoBaCkfFcFbZMVE',
#  '',
#  'https://media-exp1.licdn.com/dms/image/C4D22AQGr6_IeWxyEGw/feedshare-shrink_800-alternative/0/1606727012727?e=1613001600&v=beta&t=ojFtTNIyWVhVXXDpiwb9JuqQvKLpeYAGHggmSKJBMns',
#  'https://media-exp1.licdn.com/dms/image/C4D22AQFUhstfyge1cw/feedshare-shrink_1280-alternative/0/1606464940645?e=1613001600&v=beta&t=70_Mg-J3BFQ74liWonTLIiaQmfC3-WDZjh-LgUG5cz0',
#  '',
#  'https://media-exp1.licdn.com/dms/image/C4D22AQE7Iq2D7vWknw/feedshare-shrink_800-alternative/0/1605962916895?e=1613001600&v=beta&t=XRvkW9HXWCW9QTQnPNObb5J2wPLEBRo8dMabhO5zChc',
#  '',
#  '',
#  '',
#  '',
#  '']

# %% [markdown]
# ### tags

# %%
tag=[]
def tagGrabber(text):
    tags=' '
    for t in text:
        words=t.split()
        for word in words:
            if word.startswith('#'):
                tags=tags+word+' '
        tag.append(tags)
        tags=''
tagGrabber(post)

# %%
tag
# Out:
# [' #digitalmarketing #traffic #marketing #trafficgeneration ',
#  '#website #websitetraffic #seo #digitalmarketing ',
#  '',
#  '#digitalmarketing #traffic #marketing #trafficgeneration ',
#  '#connection #connect #letsgrow ',
#  '#digitalmarketing #traffic #marketing #trafficgeneration ',
#  '#websitetraffic #seo #digitalmarketing ',
#  '#connection #connect #letsgrow ',
#  '#digitalmarketing #traffic #marketing #trafficgeneration ',
#  '#websitetraffic #seo #digitalmarketing ',
#  '#digitalmarketing #traffic #marketing #trafficgeneration ',
#  '#digitalmarketing #traffic #marketing #trafficgeneration ',
#  '',
#  '#digitalmarketing #traffic #marketing #trafficgeneration ',
#  '#digitalmarketing #traffic #marketing #trafficgeneration ',
#  '',
#  '#connection #connect #letsgrow ',
#  '#digitalmarketing #traffic #marketing #trafficgeneration ',
#  '',
#  '#connection #connect #letsgrow ',
#  '#website #websitetraffic #seo #digitalmarketing ',
#  '',
#  '#connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '#websitetraffic #seo #digitalmarketing ',
#  '',
#  '',
#  '#websitetraffic #seo #digitalmarketing ',
#  '#connection #connect #letsgrow ',
#  '#website #websitetraffic #seo #digitalmarketing ',
#  '',
#  '#website #websitetraffic #seo #digitalmarketing ',
#  '',
#  '#websitetraffic #seo #digitalmarketing ',
#  '',
#  '',
#  '#websitetraffic #seo #digitalmarketing ',
#  '',
#  '#connections #connectingpeople #connectingcommunities #connecting #letsconnect ',
#  '',
#  '#website #websitetraffic #seo #digitalmarketing ',
#  '',
#  '',
#  '#connection #connect #letsgrow ',
#  '#website #websitetraffic #seo #digitalmarketing ',
#  '',
#  '#website #websitetraffic #seo #digitalmarketing ',
#  '#connection #connect #letsgrow ',
#  '',
#  '',
#  '#connection #connect #letsgrow ',
#  '#website #websitetraffic #seo #digitalmarketing ',
#  '',
#  '',
#  '#website #websitetraffic #seo #digitalmarketing ',
#  '#connection #connect #letsgrow ',
#  '#digitalmarketing #traffic #trafficgeneration ',
#  '#letsconnect #connection #connect #letsgrow ',
#  '#seo #digitalmarketing #traffic #trafficgeneration ',
#  '#website #websitetraffic #seo #digitalmarketing ',
#  '#connection #connect #letsgrow ',
#  '',
#  '#connection #connect #letsgrow ',
#  '#website #websitetraffic #seo #digitalmarketing ',
#  '',
#  '#connection #connect #letsgrow ',
#  '#seo #digitalmarketing #traffic #trafficgeneration ',
#  '',
#  '#connection #connect #letsgrow ',
#  '#website #websitetraffic #seo #digitalmarketing ',
#  '',
#  '#connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '',
#  '#website #websitetraffic #seo #digitalmarketing ',
#  '#connection #connect #letsgrow ',
#  '',
#  '#connection #connect #letsgrow ',
#  '#website #websitetraffic #seo #digitalmarketing ',
#  '',
#  '#connection #connect #letsgrow ',
#  '',
#  '',
#  '#connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '#seo #digitalmarketing #traffic #trafficgeneration ',
#  '',
#  '',
#  '#connection #connect #letsgrow ',
#  '#website #websitetraffic #seo #digitalmarketing ',
#  '',
#  '#connection #connect #letsgrow ',
#  '',
#  '',
#  '#connection #connect #letsgrow ',
#  '#website #websitetraffic #seo #digitalmarketing ',
#  '',
#  '',
#  '#connection #connect #letsgrow ',
#  '#seo #digitalmarketing #traffic #trafficgeneration ',
#  '',
#  '#connection #connect #letsgrow ',
#  '#seo #digitalmarketing #traffic #trafficgeneration ',
#  '#connections #connectingpeople #connectingcommunities #connecting #letsconnect ',
#  '#seo #digitalmarketing #traffic #trafficgeneration ',
#  '#connection #connect #letsgrow ',
#  '#seo #digitalmarketing #traffic #trafficgeneration ',
#  '',
#  '#website #websitetraffic #seo #digitalmarketing ',
#  '#connection #connect #letsgrow ',
#  '',
#  '#connection #connect #letsgrow ',
#  '#seo #digitalmarketing #traffic #trafficgeneration ',
#  '',
#  '#connection #connect #letsgrow ',
#  '',
#  '',
#  '#digitalmarketing #smm #seo #marketing2020 ',
#  '#connection #connect #letsgrow ',
#  '#digitalmarketing #traffic #trafficgeneration ',
#  '',
#  '',
#  '#connection #connect #letsgrow ',
#  '#seo #digitalmarketing #traffic #trafficgeneration ',
#  '',
#  '',
#  '#connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '#seo #digitalmarketing #traffic #trafficgeneration ',
#  '',
#  '#connection #connect #letsgrow ',
#  '#howtostartsellingonline ',
#  '',
#  '#connection #connect #letsgrow ',
#  '#website #websitetraffic #seo #digitalmarketing ',
#  '',
#  '#connection #connect #letsgrow ',
#  '#seo #digitalmarketing #traffic #trafficgeneration ',
#  '',
#  '#letsconnect #connection #connect #letsgrow ',
#  '#seo #digitalmarketing #traffic #trafficgeneration ',
#  '#SEO #LinkBuilding #Guide ',
#  '',
#  '',
#  '#connection #connect #letsgrow ',
#  '#connection #connect #letsgrow ',
#  '#seo #digitalmarketing #traffic #trafficgeneration ',
#  '',
#  '#letsconnect #connection #connect #letsgrow ',
#  '#website #websitetraffic #seo #digitalmarketing ',
#  '',
#  '',
#  '',
#  '',
#  '#seo #digitalmarketing #traffic #trafficgeneration ',
#  '',
#  '#connection #connect #letsgrow ',
#  '#connection #connect #letsgrow ',
#  '',
#  '#website #websitetraffic #seo #digitalmarketing ',
#  '',
#  '',
#  '',
#  '',
#  '#marketing #marketing #digitalmarketing #contentmarketing #content #contentstrategy #seo #marketingplan #marketing2020 #marketingstrategy ',
#  '#connection #connect #letsgrow ',
#  '#connection #connect #letsgrow ',
#  '#website #websitetraffic #seo #digitalmarketing ',
#  '',
#  '#connection #connect #letsgrow ',
#  '#website #websitetraffic #seo #digitalmarketing ',
#  '#connection #connect #letsgrow ',
#  '#seo #marketing2020 #titles #headlines ',
#  '#connection #connect #letsgrow ',
#  '',
#  '',
#  '#connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '',
#  '#connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '',
#  '',
#  '',
#  '#connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '#connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '',
#  '',
#  '',
#  '',
#  '#connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '#websitetraffic #seo #digitalmarketing ',
#  '#digitalmarketing #smm #seo #marketing2020 ',
#  '#connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '',
#  '#connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '',
#  '',
#  '#digitalmarketing #smm #seo #marketing2020 ',
#  '',
#  '#website #websitetraffic #seo #digitalmarketing ',
#  '#connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '#DigitalMarketing #SEOdigitalhttps://lnkd.in/d-7qUEC ',
#  '#connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '#website #websitetraffic #seo #digitalmarketing ',
#  '',
#  '#connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '',
#  '#connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '',
#  '#digitalmarketing #marketing #seo #marketing2020 ',
#  '#connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '#website #websitetraffic #seo #digitalmarketing ',
#  '',
#  '',
#  '#connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '#digitalmarketing #smm #seo #marketing2020 ',
#  '',
#  '',
#  '#connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '#website #websitetraffic #seo #digitalmarketing ',
#  '',
#  '',
#  '',
#  '#website #websitetraffic #seo #digitalmarketing ',
#  '',
#  '',
#  '#connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '#website #websitetraffic #seo #digitalmarketing ',
#  '#connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '#digitalmarketing #smm #seo #marketing2020 ',
#  '',
#  '',
#  '#website #websitetraffic #seo #digitalmarketing ',
#  '',
#  '',
#  '#connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '#website #websitetraffic #seo #digitalmarketing ',
#  '#linkbuildingstrategies ',
#  '',
#  '#connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '#website #websitetraffic #seo #digitalmarketing ',
#  '',
#  '#website #websitetraffic #seo #digitalmarketing ',
#  '',
#  '',
#  '#connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '#website #websitetraffic #seo #digitalmarketing ',
#  '',
#  '',
#  '',
#  '#connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '#websitetraffic #seo #digitalmarketing ',
#  '',
#  '',
#  '#connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '',
#  '#website #websitetraffic #seo #digitalmarketing ',
#  '',
#  '',
#  '#connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '#connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '#website #websitetraffic #seo #digitalmarketing ',
#  '',
#  '#PPC #GoogleAdshttps://lnkd.in/dv_JUmr ',
#  '#connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '#connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '#connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '#website #websitetraffic #seo #digitalmarketing ',
#  '#connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '',
#  '#connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '#website #websitetraffic #seo #digitalmarketing ',
#  '#connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '#connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '#website #websitetraffic #seo #digitalmarketing ',
#  '',
#  '#connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '',
#  '#connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '',
#  '#website #websitetraffic #seo #digitalmarketing ',
#  '',
#  '#connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '',
#  '#connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '#website #websitetraffic #seo #digitalmarketing ',
#  '',
#  '',
#  '#connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '#connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '',
#  '#WebsitePromotion #RankOnGoogle ',
#  '#connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '',
#  '',
#  '',
#  '#connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '#website #websitetraffic #seo #digitalmarketing ',
#  '#connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '#connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '#website #websitetraffic #seo #digitalmarketing ',
#  '',
#  '#connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '',
#  '',
#  '',
#  '#website #websitetraffic #seo #digitalmarketing ',
#  '#connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '',
#  '',
#  '#websitetraffic #seo #digitalmarketing ',
#  '',
#  '',
#  '#connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '#connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '',
#  '',
#  '#website #websitetraffic #seo #digitalmarketing ',
#  '#connectivity #connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '',
#  '#connectivity #connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '#websitetraffic #seo #digitalmarketing ',
#  '',
#  '',
#  '#connectivity #connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '',
#  '#connectivity #connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '#website #websitetraffic #seo #digitalmarketing ',
#  '',
#  '#connectivity #connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '#content #contentideas ',
#  '#connectivity #connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '#website #websitetraffic #seo #digitalmarketing ',
#  '#connectivity #connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '#connectivity #connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '#website #websitetraffic #seo #digitalmarketing ',
#  '',
#  '',
#  '#connectivity #connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '',
#  '#connectivity #connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '#website #websitetraffic #seo #digitalmarketing ',
#  '',
#  '#connectivity #connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '',
#  '#connectivity #connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '',
#  '#website #websitetraffic #seo #digitalmarketing ',
#  '',
#  '',
#  '',
#  '#connectivity #connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '#connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '',
#  '',
#  '#connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '#connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '',
#  '#connections #connectingpeople #connectingcommunities #connecting #letsconnect ',
#  '',
#  '#connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '#connectivity #connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '#connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '#websitetraffic #seo #digitalmarketing ',
#  '',
#  '#connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '#ImproveUX #WebsitePromotionhttps://lnkd.in/drHt45N ',
#  '#connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '#websitetraffic #seo #digitalmarketing ',
#  '',
#  '#connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '#websitetraffic #seo #digitalmarketing ',
#  '',
#  '',
#  '',
#  '',
#  '#websitetraffic #seo #digitalmarketing ',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '#connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '#connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '#connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '',
#  '',
#  '#connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '',
#  '',
#  '#connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '#LinkedInforBeginners #LinkedInViews ',
#  '',
#  '#connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '',
#  '#connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '#LinkedInforBeginners #LinkedInViews ',
#  '',
#  '#connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '',
#  '',
#  '#connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '',
#  '#connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '#Successful #Tips ',
#  '#connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '',
#  '',
#  '#connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '',
#  '#connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '',
#  '#connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '',
#  '#connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '#connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '',
#  '#connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '#Acting #Overacting ',
#  '#connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '',
#  '',
#  '#IncreaseTraffic #Guidehttps://lnkd.in/eJvbjdP?v=rrgrDiJyTGU&feature=youtu.be ',
#  '#connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '',
#  '',
#  '',
#  '#connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '',
#  '#connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '',
#  '',
#  '#connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '',
#  '#connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '',
#  '',
#  '',
#  '#connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '',
#  '#connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '',
#  '',
#  '#connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '',
#  '#connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '',
#  '#connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '',
#  '#connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '',
#  '#connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '#connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '',
#  '#connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '#websites ',
#  '#connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '',
#  '',
#  '#websites ',
#  '#connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '#connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '',
#  '#connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '',
#  '#Career #Tips ',
#  '',
#  '',
#  '#connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '',
#  '#connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '#website #websites ',
#  '#connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '#connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '',
#  '#keywords #seoguide #seocontent #seo #keywordresearch #searchengines #websitetraffic ',
#  '#connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '',
#  '',
#  '',
#  '',
#  '#connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '',
#  '',
#  '#connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '',
#  '#dream #dreams #struggles #keeptrying #smartgoals #struggle ',
#  '#connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '',
#  '',
#  '#connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '#copywriting #writing #contentwriting #bloggingtips #bloggers #seocontent #seo #websitetraffic ',
#  '',
#  '#marketing #seostrategy ',
#  '',
#  '#connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '#connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '#connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '',
#  '',
#  '#connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '#develop #improving #qualityproducts ',
#  '',
#  '',
#  '#connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '',
#  '#connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '#connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '#connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '#marketing #digitalmarketing #seo ',
#  "#NETWORKIt's #SaturdayLet's #growtogether1. #connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ",
#  '',
#  '#marketing #seo #marketing2020 #smm ',
#  '#connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '#connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '',
#  '',
#  '',
#  '#connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '',
#  '#job #findajob ',
#  '#connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '#contentwriting #contentmarketing ',
#  '#posting #post #linkedin ',
#  '',
#  '#digitalmarketing #seostrategy #seo #keywords #keywordresearch #seoguide #searchengines #websitetraffic ',
#  '#connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '#connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '',
#  '#facebook #linkedin ',
#  '#digitalmarketing #seostrategy #seo #keywords #keywordresearch #seoguide #searchengines #websitetraffic ',
#  '#connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '#LinkedInPromotion #SocialMedia ',
#  '',
#  '#connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '',
#  '#connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '',
#  '',
#  '#reputation #marketing #seo #ppc #digitalmarketing ',
#  '#marketing #digitalmarketing #marketingcampaigns #marketingcompany ',
#  '#connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '',
#  '#connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '',
#  '',
#  '#connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '#focus #focusing ',
#  '#writing #contentwriting #bloggingtips #copywriting ',
#  '#connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '#connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '',
#  '#Friday!1. #connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '#seo #seostrategy #seomarketing #seotips ',
#  '',
#  '#marketingcompany #marketingcampaigns ',
#  '',
#  '',
#  '#connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '#losing #failing ',
#  '#innovation #jeffbezos #amazon ',
#  '#connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '',
#  '#learning #acting ',
#  '#linkedin ',
#  '',
#  '#struggle #failing #fail #failure #failures #expectations #lifelesson #struggles #successfullife #lifeexperience #overcoming #success #trying #keeptrying #try ',
#  '#connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '',
#  '#connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '',
#  '',
#  '#connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '#linkedintips #linkedinleadgeneration #linkedinsalesnavigator ',
#  '',
#  '#connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '#digitalmarketing ',
#  '',
#  '',
#  '#connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '',
#  '#connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '',
#  '#marketingplans #marketingplanning #marketingstrategy #marketingstrategies #marketingstrategie #marketingstrategist #marketingplancreation #marketingplan #seo #ppc #digitalmarketing #keywords #keywordresearch #websitetraffic #seoguide #searchengines #searchenginemarketing #seoaudit ',
#  '#connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '',
#  '#connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '#connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '#connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '#connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '#connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '',
#  '#connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '#connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '#GoogleCoreUpdate #Google2020https://lnkd.in/dxkDpDu ',
#  '#connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '#connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '#SEORank #NewWebsite ',
#  '#connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '#parents #kids #education #parenting #dads #fathers ',
#  '#connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '',
#  '',
#  '#Followers #LinkedinMarketing ',
#  '#fail #failing #failure #struggles #failures #lifelesson #lifelesson #success #struggle #successfullife #overcoming #overcoming #lifeexperience #lifeexperience #trying #try #keeptrying #smartgoals ',
#  '#network #LinkedIn #connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '#connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '#connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '#connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '#connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '#connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '#connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '#connections #connectingpeople #connectingcommunities #connecting #letsconnect #connection #connectionsatwork #connected #growtogether #growyournetwork #growyourbrand ',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '']

# %%
Profile_Content={'Post':post,'Image':img,'Tag':tag}

# %%
img.pop()
# Out:
# ''

# %%
df=pd.DataFrame(Profile_Content)
df.to_csv("Linkedin.csv",index=False)

# %%
len(post)
# Out:
# 621

# %%
len(img)
# Out:
# 621

# %%
len(tag)
# Out:
# 621

# %%
df2=pd.read_csv("Linkedin.csv")

# %%
df2.head()
# Out:
#                                                 Post  \
# 0  Struggle to get traffic? Let me lead you in th...
# 1  Wanna get traffic? Share your website in the c...
# 2  Marketing research is crucial.I can explain wh...
# 3  Struggle to get traffic? Let me lead you in th...
# 4  Let`s connect and grow on Friday!1. Like this ...
#
#                                                Image  \
# 0                                                NaN
# 1                                                NaN
# 2  https://media-exp1.licdn.com/dms/image/C4D22AQ...
# 3  https://media-exp1.licdn.com/dms/image/C4D22AQ...
# 4  https://media-exp1.licdn.com/dms/image/C4D22AQ...
#
#                                                  Tag
# 0   #digitalmarketing #traffic #marketing #traffi...
# 1   #website #websitetraffic #seo #digitalmarketing
# 2                                                NaN
# 3  #digitalmarketing #traffic #marketing #traffic...
# 4                    #connection #connect #letsgrow

# %%
df2.isnull().sum()
# Out:
# Post       0
# Image    393
# Tag      263
# dtype: int64

# %%
df2.shape
# Out:
# (621, 3)
